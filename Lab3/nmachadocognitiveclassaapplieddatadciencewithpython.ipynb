# %% [markdown]
# <a href="https://colab.research.google.com/github/vmachado7/AlgorithmsUN2023I/blob/main/Lab3/nmachadocognitiveclassaapplieddatadciencewithpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://www.linkedin.com/in/nicolas-machado-narvaez-585182269

# %% [markdown]
# ![Captura.jpg](data:image/jpeg;base64,...)
